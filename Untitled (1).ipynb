# %%
#printing hello
s= 'hello'
print (s)
# Out:
# hello

# %%
#arthmetic operations
s= 1 
w= 6
sum= s+w
division= s/w
print(sum,division)
# Out:
# 7 0.16666666666666666

# %%
#area of the triangle 
a = 12
b = 15
c = 8
s = (a+b+c)/2
traingle= (s*(s-a)*(s-b)*(s-c))**0.5
print ("area of the traingle is %0.2f",traingle)
# Out:
# area of the traingle is %0.2f 47.811478747263195

# %%
#swapping
a= 10
b = 30
temp= a
a = b
b= temp
print(a)
print(b)
# Out:
# 30
# 10

# %%
#generate random number
import random
list1 = [1,4,5,6,7,8,9,23,573,75]
print(random.choice(list1))
# Out:
# 4
